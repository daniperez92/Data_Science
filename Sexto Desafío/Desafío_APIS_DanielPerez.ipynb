# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup as bs

url = "https://airbnb13.p.rapidapi.com/search-location"

querystring = {"location":"Paris","checkin":"2023-09-16","checkout":"2023-09-17","adults":"1","children":"0","infants":"0","pets":"0","page":"1","currency":"USD"}

headers = {
	"content-type": "application/octet-stream",
	"X-RapidAPI-Key": "66a03bb484msh9286dfaee259352p14b45djsn5cc060ab1de9",
	"X-RapidAPI-Host": "airbnb13.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'error': False, 'headers': {'response_time': 1543, 'response_timestamp': '2023-04-30T01:43:14.365Z', 'response_id': 24118949}, 'results': [{'id': '855813754445433021', 'url': 'https://www.airbnb.com/rooms/855813754445433021', 'deeplink': 'https://www.airbnb.com/rooms/855813754445433021?check_in=2023-09-16&check_out=2023-09-17&adults=1&children=0&infants=0&pets=0', 'position': 1, 'name': 'Love Nest, Marais', 'bathrooms': 1, 'bedrooms': 1, 'beds': 1, 'city': 'Paris', 'images': ['https://a0.muscache.com/im/pictures/f5d51539-7de7-4b4e-bd60-4ffb37f58e2e.jpg?im_w=720', 'https://a0.muscache.com/im/pictures/833da532-f2f0-4438-8a8a-3307e0843ca2.jpg?im_w=720', 'https://a0.muscache.com/im/pictures/d42d304f-f13e-4530-927e-8c7065137e1e.jpg?im_w=720', 'https://a0.muscache.com/im/pictures/3d13caa3-bbab-4357-b774-78b0d2f2fe23.jpg?im_w=720', 'https://a0.muscache.com/im/pictures/06b19574-a615-49a6-ab3d-607a9f4b6fa3.jpg?im_w=720', 'https://a0.muscache.com/im/pictures/f2ebab7e-d32b-4d2f-910a-734b22bc8ded.jpg?im_w=720', 'https://a0.muscache.com/im/pictures/870dc451-8b9b-490b-864f-71fb61d05c6b.jpg?im_w=720', 'https://a0.muscache.com/im/pictures/3099566a-6d8f-45b9-9125-27d76d9a6872.jpg?im_w=720'], 'hostThumbnail': 'https://a0.muscache.com/im/Portrait/Avatars/messaging/b3e03835-ade9-4eb7-a0bb-2466ab9a534d.jpg?im_policy=medq_w_text&im_t=A&im_w=240&im_f=airbnb-cereal-medium.ttf&im_c=ffffff', 'isSuperhost': False, 'rareFind': True, 'lat': 48.85742395903405, 'lng': 2.3690506103968714, 'persons': 2, 'reviewsCount': 7, 'rating': 4.86, 'type': 'Entire rental unit', 'userId': 507176949, 'address': 'Paris, Île-de-France, France', 'amenityIds': [1, 35, 4, 37, 8, 40, 12, 45, 77, 51, 85, 54, 90, 91, 93, 30, 94], 'previewAmenities': ['Wifi', 'Kitchen'], 'cancelPolicy': 'CANCEL_MODERATE', 'price': {'rate': 100, 'currency': 'USD', 'total': 100, 'priceItems': [{'amount': 75}, {'amount': 6}, {'amount': 14}, {'amount': 5}]}}, {'id': '728674358920317373', 'url': 'https://www.airbnb.com/rooms/728674358920317373', 'deeplink': 'https://www.airbnb.com/rooms/728674358920317373?check_in=2023-09-16&check_out=2023-09-17&adults=1&children=0&infants=0&pets=0', 'position': 2, 'name': 'A private room in the city center of Paris', 'bathrooms': 1, 'bedrooms': 1, 'beds': 1, 'city': 'Paris', 'images': ['https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/814c3e74-b5a8-46b5-a077-69e4d1a3bb58.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/fc1c98b6-50f3-41aa-a62f-037c941296c3.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/740e98af-9e28-4fb3-924f-dbf7e205d264.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/3b34b066-0f41-4f56-8d83-8b3e9e8061eb.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/1eda0f52-9356-4be9-ac8b-6bdbe26ccf8d.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/0debf79c-028d-4f45-807d-5b12d50d67fd.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/98afefe8-46da-47a2-b881-7c9f756cb912.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/06c252a2-9e7f-446b-9457-dcad762f8109.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/d0344dce-1c2a-4213-91f7-8b42d09099a6.jpeg?im_w=720', 'https://a0.muscache.com/im/pictures/miso/Hosting-728674358920317373/original/badbac11-ef3e-4a76-bb5d-8109e0194e07.jpeg?im_w=720'], 'hostThumbnail': 'https://a0.muscache.com/im/pictures/user/21cd4d65-c78b-46a8-bb29-cb5db1028dd2.jpg?aki_policy=profile_x_medium', 'isSuperhost': True, 'rareFind': False, 'lat': 48.84552069999999, 'lng': 2.3884318, 'persons': 1, 'reviewsCount': 54, 'rating': 4.87, 'type': 'Private room in condo', 'userId': 23679619, 'address': 'Paris, Île-de-France, France', 'amenityIds': [129, 4, 8, 137, 77, 79, 657, ...

# %%
texto = response.text
jsondata = json.loads(texto)

# %%
datos = response.json()["results"]
dfapi = pd.DataFrame.from_dict(datos)
dfapi.head()
# Out:
#                    id                                              url  \
# 0  855813754445433021  https://www.airbnb.com/rooms/855813754445433021
# 1  728674358920317373  https://www.airbnb.com/rooms/728674358920317373
# 2            43449093            https://www.airbnb.com/rooms/43449093
# 3  774582581519038073  https://www.airbnb.com/rooms/774582581519038073
# 4  564211617565288722  https://www.airbnb.com/rooms/564211617565288722
#
#                                             deeplink  position  \
# 0  https://www.airbnb.com/rooms/85581375444543302...         1
# 1  https://www.airbnb.com/rooms/72867435892031737...         2
# 2  https://www.airbnb.com/rooms/43449093?check_in...         3
# 3  https://www.airbnb.com/rooms/77458258151903807...         4
# 4  https://www.airbnb.com/rooms/56421161756528872...         5
#
#                                          name  bathrooms  bedrooms  beds  \
# 0                           Love Nest, Marais        1.0         1     1
# 1  A private room in the city center of Paris        1.0         1     1
# 2                  Room in the heart of Paris        1.0         1     1
# 3                             Chill out room.        1.0         1     1
# 4  PRIVATE STUDIO IN ARCHITECT HOUSE IN PARIS        1.0         1     1
#
#      city                                             images  ... persons  \
# 0   Paris  [https://a0.muscache.com/im/pictures/f5d51539-...  ...       2
# 1   Paris  [https://a0.muscache.com/im/pictures/miso/Host...  ...       1
# 2   Paris  [https://a0.muscache.com/im/pictures/miso/Host...  ...       1
# 3  Clichy  [https://a0.muscache.com/im/pictures/miso/Host...  ...       1
# 4   Paris  [https://a0.muscache.com/im/pictures/miso/Host...  ...       2
#
#    reviewsCount  rating                               type     userId  \
# 0             7    4.86                 Entire rental unit  507176949
# 1            54    4.87              Private room in condo   23679619
# 2           260    4.53                 Entire rental unit  271527319
# 3            23    4.96  Private room in bed and breakfast  296443273
# 4            77    4.87        Private room in rental unit  156461073
#
#                          address  \
# 0   Paris, Île-de-France, France
# 1   Paris, Île-de-France, France
# 2   Paris, Île-de-France, France
# 3  Clichy, Île-de-France, France
# 4   Paris, Île-de-France, France
#
#                                           amenityIds         previewAmenities  \
# 0  [1, 35, 4, 37, 8, 40, 12, 45, 77, 51, 85, 54, ...          [Wifi, Kitchen]
# 1  [129, 4, 8, 137, 77, 79, 657, 146, 85, 86, 89,...  [Wifi, Kitchen, Washer]
# 2  [35, 611, 4, 103, 40, 104, 42, 11, 44, 45, 77,...                   [Wifi]
# 3         [1, 35, 227, 4, 5, 37, 8, 42, 15, 47, 287]          [Wifi, Kitchen]
# 4  [4, 8, 10, 394, 12, 77, 79, 280, 90, 27, 91, 3...  [Wifi, Kitchen, Washer]
#
#                              cancelPolicy  \
# 0                         CANCEL_MODERATE
# 1  CANCEL_BETTER_STRICT_WITH_GRACE_PERIOD
# 2                         CANCEL_MODERATE
# 3                         CANCEL_FLEXIBLE
# 4                         CANCEL_FLEXIBLE
#
#                                                price
# 0  {'rate': 100, 'currency': 'USD', 'total': 100,...
# 1  {'rate': 79, 'currency': 'USD', 'total': 79, '...
# 2  {'rate': 86, 'currency': 'USD', 'total': 86, '...
# 3  {'rate': 49, 'currency': 'USD', 'total': 49, '...
# 4  {'rate': 95, 'currency': 'USD', 'total': 95, '...
#
# [5 rows x 25 columns]

# %%
dfapi.shape
# Out:
# (40, 25)

# %%
dfapi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                40 non-null     object
#  1   url               40 non-null     object
#  2   deeplink          40 non-null     object
#  3   position          40 non-null     int64
#  4   name              40 non-null     object
#  5   bathrooms         40 non-null     float64
#  6   bedrooms          40 non-null     int64
#  7   beds              40 non-null     int64
#  8   city              40 non-null     object
#  9   images            40 non-null     object
#  10  hostThumbnail     40 non-null     object
#  11  isSuperhost       40 non-null     bool
#  12  rareFind          40 non-null     bool
#  13  lat               40 non-null     float64
#  14  lng               40 non-null     float64
#  15  persons           40 non-null     int64
#  16  reviewsCount      40 non-null     int64
#  17  rating            35 non-null     float64
#  18  type              40 non-null     object
#  19  userId            40 non-null     int64
#  20  address           40 non-null     object
#  21  amenityIds        40 non-null     object
#  22  previewAmenities  40 non-null     object
#  23  cancelPolicy      40 non-null     object
#  24  price             40 non-null     object
# dtypes: bool(2), float64(4), int64(6), object(13)
# memory usage: 7.4+ KB

# %% [markdown]
# *Las "AmenityID" se corresponden con las siguientes:*
#
# 2 - Kitchen
# 4 - Wifi
# 5 - Air conditioning
# 7 - Pool
# 8 - Kitchen
# 9 - Free parking on premises
# 11 - Smoking allowed
# 12 - Pets allowed
# 15 - Gym
# 16 - Breakfast
# 21 - Elevator
# 25 - Hot tub
# 27 - Indoor fireplace
# 30 - Heating
# 33 - Washer
# 34 - Dryer
# 35 - Smoke alarm
# 36 - Carbon monoxide alarm
# 41 - Shampoo
# 44 - Hangers
# 45 - Hair dryer
# 46 - Iron
# 47 - Laptop-friendly workspace
# 51 - Self check-in
# 58 - TV
# 64 - High chair
# 78 - Private bathroom
# 109 - Wide hallways
# 110 - No stairs or steps to enter
# 111 - Wide entrance for guests
# 112 - Step-free path to entrance
# 113 - Well-lit path to entrance
# 114 - Disabled parking spot
# 115 - No stairs or steps to enter
# 116 - Wide entrance
# 117 - Extra space around bed
# 118 - Accessible-height bed
# 120 - No stairs or steps to enter
# 121 - Wide doorway to guest bathroom
# 123 - Bathtub with bath chair
# 125 - Accessible-height toilet
# 127 - No stairs or steps to enter
# 128 - Wide entryway
# 136 - Handheld shower head
# 286 - Crib
# 288 - Electric profiling bed
# 289 - Mobile hoist
# 290 - Pool with pool hoist
# 291 - Ceiling hoist
# 294 - Fixed grab bars for shower
# 295 - Fixed grab bars for toilet
# 296 - Step-free shower
# 297 - Shower chair
# 347 - Piano
# 608 - Extra space around toilet
# 609 - Extra space around shower
